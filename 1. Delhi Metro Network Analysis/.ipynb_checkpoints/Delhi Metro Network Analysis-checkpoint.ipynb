# %% [markdown]
# ## 1. Importing the libraries:

# %%
import pandas as pd
import numpy as np
import folium
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default = 'plotly_white'

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Reading the dataset:

# %%
metro_data = pd.read_csv("Delhi-Metro-Network.csv")

# %%
metro_data.head(2)
# Out:
#    Station ID         Station Name  Distance from Start (km)       Line  \
# 0           1             Jhil Mil                      10.3   Red line
# 1           2  Welcome [Conn: Red]                      46.8  Pink line
#
#   Opening Date Station Layout  Latitude  Longitude
# 0   2008-04-06       Elevated  28.67579   77.31239
# 1   2018-10-31       Elevated  28.67180   77.27756

# %% [markdown]
# ## 3. Performing EDA:

# %%
metro_data.describe()
# Out:
#        Station ID  Distance from Start (km)    Latitude   Longitude
# count  285.000000                285.000000  285.000000  285.000000
# mean   143.000000                 19.218947   28.595428   77.029315
# std     82.416625                 14.002862    0.091316    2.875400
# min      1.000000                  0.000000   27.920862   28.698807
# 25%     72.000000                  7.300000   28.545828   77.107130
# 50%    143.000000                 17.400000   28.613453   77.207220
# 75%    214.000000                 28.800000   28.666360   77.281165
# max    285.000000                 52.700000   28.878965   77.554479

# %% [markdown]
# #### 3.1 Checking the NULL Values:

# %%
metro_data.isna().sum()
# Out:
# Station ID                  0
# Station Name                0
# Distance from Start (km)    0
# Line                        0
# Opening Date                0
# Station Layout              0
# Latitude                    0
# Longitude                   0
# dtype: int64

# %% [markdown]
# #### 3.2 Checking the data types:

# %%
metro_data.dtypes
# Out:
# Station ID                    int64
# Station Name                 object
# Distance from Start (km)    float64
# Line                         object
# Opening Date                 object
# Station Layout               object
# Latitude                    float64
# Longitude                   float64
# dtype: object

# %% [markdown]
# ###### The opening date column is represented as an object, so let's convert it to datetime object:

# %%
metro_data.head(2)
# Out:
#    Station ID         Station Name  Distance from Start (km)       Line  \
# 0           1             Jhil Mil                      10.3   Red line
# 1           2  Welcome [Conn: Red]                      46.8  Pink line
#
#   Opening Date Station Layout  Latitude  Longitude
# 0   2008-04-06       Elevated  28.67579   77.31239
# 1   2018-10-31       Elevated  28.67180   77.27756

# %%
metro_data['Opening Date'] = pd.to_datetime(metro_data['Opening Date'])

# %%
metro_data.dtypes
# Out:
# Station ID                           int64
# Station Name                        object
# Distance from Start (km)           float64
# Line                                object
# Opening Date                datetime64[ns]
# Station Layout                      object
# Latitude                           float64
# Longitude                          float64
# dtype: object

# %% [markdown]
# There are no any NULL values, and the data type for Opening Date column has been changed to datetime format,
# now, let's start the analysis.

# %% [markdown]
# ## 4. Geo-Spatial Analysis:

# %%
metro_data['Line'].value_counts()
# Out:
# Blue line            49
# Pink line            38
# Yellow line          37
# Voilet line          34
# Red line             29
# Magenta line         25
# Aqua line            21
# Green line           21
# Rapid Metro          11
# Blue line branch      8
# Orange line           6
# Gray line             3
# Green line branch     3
# Name: Line, dtype: int64

# %%
metro_data['Line'].value_counts().sum()
# Out:
# 285

# %%
metro_data.shape
# Out:
# (285, 8)

# %%
print(f"In total we have: {metro_data['Line'].nunique()} unique lines, " 
      "so, let's assign a unique color to them so that we can plot it.")
# Out:
# In total we have: 13 unique lines, so, let's assign a unique color to them so that we can plot it.

# %% [markdown]
# #### 4.1 Assigning unique colors to each of the railway lines:

# %%
line_colors = {
    "Blue line": "blue",
    "Pink line": "pink",
    "Yellow line": "yellow",
    "Voilet line": "purple",
    "Red line": "red",
    "Magenta line": "black",
    "Aqua line": "lightblue",
    "Green line": "green",
    "Rapid Metro": "cadetblue",
    "Blue line branch": "darkpurple",
    "Orange line": "orange",
    "Gray line": "beige",
    "Green line branch": "lightgreen"
}

# %% [markdown]
# Let's visualize the tracks now:

# %%
print("The map below shows the line connection of different railway lines, hover over to get more info")
delhi_map_w_line_tooltip = folium.Map(location=[28.7041, 77.1025], zoom_start=11)
for index, row  in metro_data.iterrows():
    line = row['Line']
    color = line_colors.get(line, 'black')  # If line name is not found in dictionary, the default is black
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup = row['Station Name'],
        tooltip=f" Station name: {row['Station Name']} \n Line: {line}",
        icon=folium.Icon(color=color)
    ).add_to(delhi_map_w_line_tooltip)

delhi_map_w_line_tooltip
# Out:
# The map below shows the line connection of different railway lines, hover over to get more info
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15c2e4da1d93b2bbc061d6083a187af4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15c2e4da1d93b2bbc061d6083a187af4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15c2e4da1d93b2bbc061d6083a187af4 = L.map(
#                 &quot;map_15c2e4da1d93b2bbc061d6083a187af4&quot;,
#                 {
#                     center: [28.7041, 77.1025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60131c27e12fdd5054533f004f6b1729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_60131c27e12fdd5054533f004f6b1729.addTo(map_15c2e4da1d93b2bbc061d6083a187af4);
#
#
#             var marker_2cb511709d51f5aeff47b10e02b1875a = L.marker(
#                 [28.67579, 77.31239],
#                 {}
#             ).addTo(map_15c2e4da1d93b2bbc061d6083a187af4);
#
#
#             var icon_0f801279fba1c13c83e002a4c319c818 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2cb511709d51f5aeff47b10e02b1875a.setIcon(icon_0f801279fba1c13c83e002a4c319c818);
#
#
#         var popup_d5bfa51a4142d80a2e3764a1f08028b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c63052abb9f4e17e3e1bc378a78be95 = $(`&lt;div id=&quot;html_0c63052abb9f4e17e3e1bc378a78be95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jhil Mil&lt;/div&gt;`)[0];
#                 popup_d5bfa51a4142d80a2e3764a1f08028b8.setContent(html_0c63052abb9f4e17e3e1bc378a78be95);
#
#
#
#         marker_2cb511709d51f5aeff47b10e02b1875a.bindPopup(popup_d5bfa51a4142d80a2e3764a1f08028b8)
#         ;
#
#
#
#
#             marker_2cb511709d51f5aeff47b10e02b1875a.bindTooltip(
#                 `&lt;div&gt;
#                       Station name: Jhil Mil
#  Line: Red line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4ae45f772d6f241c210b022533224393 = L.marker(
#                 [28.6718, 77.27756],
#                 {}
#             ).addTo(map_15c2e4da1d93b2bbc061d6083a187af4);
#
#
#             var icon_cec222d9ebe4bca96368f14dc127ad04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ae45f772d6f241c210b022533224393.setIcon(icon_cec222d9ebe4bca96368f14dc127ad04);
#
#
#         var popup_f77525874bcfe5839a3e37636c6e32d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3dc2bbb0c9d7253d829bd4936e23dc8 = $(`&lt;div id=&quot;html_f3dc2bbb0c9d7253d829bd4936e23dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome [Conn: Red]&lt;/div&gt;`)[0];
#                 popup_f77525874bcfe5839a3e37636c6e32d9.setContent(html_f3dc2bbb0c9d7253d829bd4936e23dc8);
#
#
#
#         marker_4ae45f772d6f241c210b022533224393.bindPopup(popup_f77525874bcfe5839a3e37636c6e32d9)
#         ;
#
#
#
#
#             marker_4ae45f772d6f241c210b022533224393.bindTooltip(
#                 `&lt;div&gt;
#                       Station name: Welcome [Conn: Red]
#  Line: Pink line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fa05168b5f966ea2fc0cea0a3767e119 = L.marker(
#                 [28.4936, 77.0935],
#                 {}
#             ).addTo(map_15c2e4da1d93b2bbc061d6083a187af4);
#
#
#             var icon_a1ec98615a8255b7797022b0e4ea3264 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa05168b5f966ea2fc0cea0a3767e119.setIcon(icon_a1ec98615a8255b7797022b0e4ea3264);
#
#
#         var popup_896cab5c1a3cbb1f0dfad95a69b59e6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4502d30248dcd95a0682ebfb003c2b53 = $(`&lt;div id=&quot;html_4502d30248dcd95a0682ebfb003c2b53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DLF Phase 3&lt;/div&gt;`)[0];
#                 popup_896cab5c1a3cbb1f0dfad95a69b59e6b.setContent(html_4502d30248dcd95a0682ebfb003c2b53);
#
#
#
#         marker_fa05168b5f966ea2fc0cea0a3767e119

# %% [markdown]
# ## 5. The growth of railways over the time:

# %% [markdown]
# #### 5.1 Adding an extra column for the years:

# %%
metro_data['year'] = metro_data['Opening Date'].dt.year

# %%
metro_data.head(2)
# Out:
#    Station ID         Station Name  Distance from Start (km)       Line  \
# 0           1             Jhil Mil                      10.3   Red line
# 1           2  Welcome [Conn: Red]                      46.8  Pink line
#
#   Opening Date Station Layout  Latitude  Longitude  year
# 0   2008-04-06       Elevated  28.67579   77.31239  2008
# 1   2018-10-31       Elevated  28.67180   77.27756  2018

# %%
num_of_stations_per_year = metro_data['year'].value_counts()
num_of_stations_per_year_df = num_of_stations_per_year.reset_index()
num_of_stations_per_year_df.head(2)
# Out:
#    index  year
# 0   2018    64
# 1   2010    54

# %% [markdown]
# #### 5.2 Renaming the columns in the new railway count dataframe:

# %%
num_of_stations_per_year_df.rename(columns={
    "index": "Year",
    "year": "Number of railway tracks"
}, inplace=True)

# %%
fig = px.bar(data_frame=num_of_stations_per_year_df, x='Year', y='Number of railway tracks', 
            text='Number of railway tracks',
            title="Number of metro stations opened each year from 2002 to 2019")

fig.update_layout(yaxis_title = "Number of stations",
                 xaxis_tickangle=-45, xaxis=dict(tickmode='linear'))

fig.update_traces(textposition='outside')
fig.show()
# Out:
# <div>                            <div id="697dd1a3-e164-4e8b-9f0f-ee9cb7ca0474" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("697dd1a3-e164-4e8b-9f0f-ee9cb7ca0474")) {                    Plotly.newPlot(                        "697dd1a3-e164-4e8b-9f0f-ee9cb7ca0474",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Number of railway tracks=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[64.0,54.0,37.0,28.0,18.0,17.0,13.0,13.0,11.0,9.0,6.0,5.0,4.0,3.0,3.0],"textposition":"outside","x":[2018,2010,2019,2005,2017,2009,2011,2015,2004,2006,2002,2013,2003,2008,2014],"xaxis":"x","y":[64,54,37,28,18,17,13,13,11,9,6,5,4,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %% [markdown]
# Some of the years didn't have any new connection, it could be due to various reasons:
# 1. Lack of planning.
# 2. Financial fundings or
# 3. Construction challenges
#
# From the above chart, **2018 has the highest number of railway tracks opened.**
# Now, let's see which and how many tracks were opened in that year.

# %%
metro_2018_data = metro_data[metro_data['year'] == 2018][['Station Name', 'Distance from Start (km)', 'Station Layout']]

# %%
print(f"In the year 2018, a total of {metro_2018_data['Distance from Start (km)'].sum():.2f} KM distance were covered "
     "with the addition of new railway tracks.")
# Out:
# In the year 2018, a total of 1540.90 KM distance were covered with the addition of new railway tracks.

# %%
station_layoout = metro_2018_data['Station Layout'].value_counts().reset_index()

# %%
station_layoout.rename(columns={
    "index": "Station Layout",
    "Station Layout": "Total"
}, inplace=True)

# %%
fig = px.bar(data_frame=station_layoout, x="Station Layout", y="Total", color="Station Layout", 
       text="Total", title="Total of different layouts added in the year 2018")

fig.update_traces(textposition='outside', textfont_size=14)
fig.show()
# Out:
# <div>                            <div id="b662c09c-abc1-4d63-8f05-10d61c664fc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b662c09c-abc1-4d63-8f05-10d61c664fc0")) {                    Plotly.newPlot(                        "b662c09c-abc1-4d63-8f05-10d61c664fc0",                        [{"alignmentgroup":"True","hovertemplate":"Station Layout=%{x}<br>Total=%{text}<extra></extra>","legendgroup":"Elevated","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Elevated","offsetgroup":"Elevated","orientation":"v","showlegend":true,"text":[38.0],"textposition":"outside","x":["Elevated"],"xaxis":"x","y":[38],"yaxis":"y","type":"bar","textfont":{"size":14}},{"alignmentgroup":"True","hovertemplate":"Station Layout=%{x}<br>Total=%{text}<extra></extra>","legendgroup":"Underground","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Underground","offsetgroup":"Underground","orientation":"v","showlegend":true,"text":[26.0],"textposition":"outside","x":["Underground"],"xaxis":"x","y":[26],"yaxis":"y","type":"bar","textfont":{"size":14}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %% [markdown]
# ## 6. Line Analysis:

# %% [markdown]
# Now, let's analyize the number of lines in terms of the number of stations and the average distance
# between the stations.

# %%
metro_data.head()
# Out:
#    Station ID         Station Name  Distance from Start (km)          Line  \
# 0           1             Jhil Mil                      10.3      Red line
# 1           2  Welcome [Conn: Red]                      46.8     Pink line
# 2           3          DLF Phase 3                      10.0   Rapid Metro
# 3           4           Okhla NSIC                      23.8  Magenta line
# 4           5           Dwarka Mor                      10.2     Blue line
#
#   Opening Date Station Layout   Latitude  Longitude  year
# 0   2008-04-06       Elevated  28.675790  77.312390  2008
# 1   2018-10-31       Elevated  28.671800  77.277560  2018
# 2   2013-11-14       Elevated  28.493600  77.093500  2013
# 3   2017-12-25       Elevated  28.554483  77.264849  2017
# 4   2005-12-30       Elevated  28.619320  77.033260  2005

# %%
total_distance_per_line = metro_data.groupby("Line")['Distance from Start (km)'].max().reset_index()
total_number_of_lines = metro_data['Line'].value_counts().reset_index()

# %%
total_number_of_lines.rename(columns={'index': 'Line', 'Line':'total_stops'}, inplace=True)

# %%
distance_per_line_df = pd.merge(total_distance_per_line, total_number_of_lines, on='Line', how='inner')

# %%
distance_per_line_df['average_km_per_station'] = distance_per_line_df['Distance from Start (km)'] / (distance_per_line_df['total_stops'] - 1)

# %% [markdown]
# ###### The summary of total distance covered,total number of stops,and average distance in KM per station:

# %%
distance_per_line_df
# Out:
#                  Line  Distance from Start (km)  total_stops  \
# 0           Aqua line                      27.1           21
# 1           Blue line                      52.7           49
# 2    Blue line branch                       8.1            8
# 3           Gray line                       3.9            3
# 4          Green line                      24.8           21
# 5   Green line branch                       2.1            3
# 6        Magenta line                      33.1           25
# 7         Orange line                      20.8            6
# 8           Pink line                      52.6           38
# 9         Rapid Metro                      10.0           11
# 10           Red line                      32.7           29
# 11        Voilet line                      43.5           34
# 12        Yellow line                      45.7           37
#
#     average_km_per_station
# 0                 1.355000
# 1                 1.097917
# 2                 1.157143
# 3                 1.950000
# 4                 1.240000
# 5                 1.050000
# 6                 1.379167
# 7                 4.160000
# 8                 1.421622
# 9                 1.000000
# 10                1.167857
# 11                1.318182
# 12                1.269444

# %% [markdown]
# #### Now, let's visualize these results:

# %%
# Creating the sub plots first with 1*2 dimension:
fig = make_subplots(rows=1, cols=2, subplot_titles=("Average distance in KM per stops", "Total number of stops per line"),
                   horizontal_spacing=0.2)

# Plotting the average distance in KM per stops:
fig.add_trace(go.Bar(y=distance_per_line_df['Line'], x=distance_per_line_df['average_km_per_station'],
                    name='Average distance in KM per station', marker_color='crimson', orientation='h'),
             row=1, col=1)



# Plotting the count of stops in each lines:
fig.add_trace(go.Bar(x=distance_per_line_df['total_stops'], y=distance_per_line_df['Line'],
                    name='Tota Number of stops in Each Line', marker_color='navy',orientation='h'),
             row=1, col=2)


# Updating X and Y axis properties:
fig.update_xaxes(title_text="Average Distance in KM", row=1, col=1)
fig.update_xaxes(title_text="Number of stations", row=1,col=2)

fig.update_yaxes(title_text="Metro Lines", row=1, col=1)

# Update layout:
fig.update_layout(height=550, width=950, title_text="Metro Line Analysis")

fig.show()
# Out:
# <div>                            <div id="d39eaa63-5c62-4c44-8f18-d3fb7a4efe09" class="plotly-graph-div" style="height:550px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d39eaa63-5c62-4c44-8f18-d3fb7a4efe09")) {                    Plotly.newPlot(                        "d39eaa63-5c62-4c44-8f18-d3fb7a4efe09",                        [{"marker":{"color":"crimson"},"name":"Average distance in KM per station","orientation":"h","x":[1.355,1.0979166666666667,1.157142857142857,1.95,1.24,1.05,1.3791666666666667,4.16,1.4216216216216218,1.0,1.167857142857143,1.3181818181818181,1.2694444444444446],"y":["Aqua line","Blue line","Blue line branch","Gray line","Green line","Green line branch","Magenta line","Orange line","Pink line","Rapid Metro","Red line","Voilet line","Yellow line"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"navy"},"name":"Tota Number of stops in Each Line","orientation":"h","x":[21,49,8,3,21,3,25,6,38,11,29,34,37],"y":["Aqua line","Blue line","Blue line branch","Gray line","Green line","Green line branch","Magenta line","Orange line","Pink line","Rapid Metro","Red line","Voilet line","Yellow line"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type ...

# %% [markdown]
# ## 7. Station Layout Analysis:

# %%
station_layout_df = metro_data['Station Layout'].value_counts().reset_index()
station_layout_df
# Out:
#          index  Station Layout
# 0     Elevated             214
# 1  Underground              68
# 2     At-Grade               3

# %%
fig = px.bar(data_frame=station_layout_df, x='index', y='Station Layout', color='index',
        title='Delhi Metro Station Layout Count', text='Station Layout',
        labels={'index':'Layouts', 'Station Layout':'Number of stations'})


fig.update_traces(textposition = 'outside')


fig.show()
# Out:
# <div>                            <div id="3ba0c3ba-e689-420f-9856-619111bbf729" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ba0c3ba-e689-420f-9856-619111bbf729")) {                    Plotly.newPlot(                        "3ba0c3ba-e689-420f-9856-619111bbf729",                        [{"alignmentgroup":"True","hovertemplate":"Layouts=%{x}<br>Number of stations=%{text}<extra></extra>","legendgroup":"Elevated","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Elevated","offsetgroup":"Elevated","orientation":"v","showlegend":true,"text":[214.0],"textposition":"outside","x":["Elevated"],"xaxis":"x","y":[214],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Layouts=%{x}<br>Number of stations=%{text}<extra></extra>","legendgroup":"Underground","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Underground","offsetgroup":"Underground","orientation":"v","showlegend":true,"text":[68.0],"textposition":"outside","x":["Underground"],"xaxis":"x","y":[68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Layouts=%{x}<br>Number of stations=%{text}<extra></extra>","legendgroup":"At-Grade","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At-Grade","offsetgroup":"At-Grade","orientation":"v","showlegend":true,"text":[3.0],"textposition":"outside","x":["At-Grade"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...
